# %%
# !pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.13/dist-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.13/dist-packages (from gymnasium) (2.1.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.13/dist-packages (from gymnasium) (4.16.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.13/dist-packages (from gymnasium) (0.0.6)

# %%
import gymnasium as gym
import random

# %% [markdown]
# **Part-A Random Agent on CliffWalking**

# %%
import gymnasium as gym
import random

# Create environment
env = gym.make("CliffWalking-v1")

# Number of episodes
episodes = 10

rewards = []

for episode in range(1, episodes + 1):

    # Reset environment
    state, info = env.reset()

    total_reward = 0
    terminated = False
    truncated = False

    while not (terminated or truncated):

        # Identify available actions
        action = env.action_space.sample()

        # Execute action
        next_state, reward, terminated, truncated, info = env.step(action)

        # Update state
        state = next_state

        # Add reward
        total_reward += reward

    rewards.append(total_reward)

    print(f"Episode {episode}: Total Reward = {total_reward}")

# Calculate average reward
average_reward = sum(rewards) / len(rewards)

print("\nCliffWalking Results")
print("--------------------")
print("Total Episodes:", episodes)
print("Average Reward:", average_reward)

env.close()
# Out:
# Episode 1: Total Reward = -78144
# Episode 2: Total Reward = -99192
# Episode 3: Total Reward = -14800
# Episode 4: Total Reward = -16206
# Episode 5: Total Reward = -156783
# Episode 6: Total Reward = -6704
# Episode 7: Total Reward = -19857
# Episode 8: Total Reward = -134409
# Episode 9: Total Reward = -6109
# Episode 10: Total Reward = -65757
#
# CliffWalking Results
# --------------------
# Total Episodes: 10
# Average Reward: -59796.1

# %% [markdown]
# **Part B — Random Agent on Taxi**

# %%
import gymnasium as gym
import random

# Create environment
env = gym.make("Taxi-v4")

# Number of episodes
episodes = 10

rewards = []

for episode in range(1, episodes + 1):

    # Reset environment
    state, info = env.reset()

    total_reward = 0
    terminated = False
    truncated = False

    while not (terminated or truncated):

        # Identify available actions
        action = env.action_space.sample()

        # Execute action
        next_state, reward, terminated, truncated, info = env.step(action)

        # Update state
        state = next_state

        # Add reward
        total_reward += reward

    rewards.append(total_reward)

    print(f"Episode {episode}: Total Reward = {total_reward}")

# Calculate average reward
average_reward = sum(rewards) / len(rewards)

print("\nTaxi Results")
print("------------")
print("Total Episodes:", episodes)
print("Average Reward:", average_reward)

env.close()
# Out:
# Episode 1: Total Reward = -866
# Episode 2: Total Reward = -767
# Episode 3: Total Reward = -632
# Episode 4: Total Reward = -776
# Episode 5: Total Reward = -749
# Episode 6: Total Reward = -875
# Episode 7: Total Reward = -695
# Episode 8: Total Reward = -785
# Episode 9: Total Reward = -740
# Episode 10: Total Reward = -902
#
# Taxi Results
# ------------
# Total Episodes: 10
# Average Reward: -778.7
